# %% [markdown]
# ## Import libraries

# %%
#General
import numpy as np
import pandas as pd
#from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import random
import time

#Image loading and processing
import os
from matplotlib import image
#from skimage.transform import resize
import cv2

#Model development
import tensorflow as tf
from tensorflow.keras import datasets, layers, models, optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input as VGG16_preprocess_input
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input as RN50_preprocess_input
from tensorflow.keras.optimizers import SGD

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
import tensorflow as tf
if tf.test.gpu_device_name():
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TF")
# Out:
# Default GPU Device: /device:GPU:0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
import tensorflow as tf
print(tf.test.is_built_with_cuda())
# Out:
# True

# %% [markdown]
# ## Define functions

# %%
def generate_image_set(breed_list, clean='y', threshold = 0, pic_size = (400,400,3)):

#Set up list of dog pics:
    path = 'dog_pics/'
    clean_path = 'clean_dog_pics/'
    file_list = sorted(os.listdir('dog_pics/'))
    file_list = file_list[1:]
    clean_file_list = sorted(os.listdir('clean_dog_pics/'))
    clean_file_list = clean_file_list[1:]

#Load pictures and labels from a specified breed list
    print('Loading pictures...')
    
    labels=[]
    images=list()
    for file in clean_file_list:
        dog_breed=file[6:-7]
        pic_pc = int(file[:-4].split('_')[-1])
        if dog_breed in breed_list:
            if pic_pc >= threshold:
                if clean == 'y':
                    data = np.asarray(image.imread(clean_path+file))
                else:
                    load_filename = file[:-7]+'.jpg'
                    data = np.asarray(image.imread(path+load_filename))
                if data.shape!=pic_size:
                    data = cv2.resize(data, dsize=(pic_size[1], pic_size[0]), interpolation=cv2.INTER_CUBIC)
#                    data = resize(data,pic_size, anti_aliasing=True)

                images.append(data)
                labels.append(dog_breed)                
    print('Setting up numpy array')
    images = np.array(images)
    
    print('Number of loaded images: ',len(images))
    print('Number of labels: ', len(labels))

#Set up label dictionaries and convert labels from text to integers for modelling
    breed_dict = {}
    for i in range (0, len(breed_list)):
        breed_dict[breed_list[i]]=i
    print(breed_dict)
    inv_breed_dict = {}
    for i in range (0, len(breed_list)):
        inv_breed_dict[i]=breed_list[i]
    print(inv_breed_dict)
    int_labels = [breed_dict[breed] for breed in labels]


#Set up train test split
    print('Setting up train/test split')
    train_images, test_images, train_labels, test_labels =\
    train_test_split(images, int_labels, test_size = 0.2, 
                     random_state = 1, shuffle = True, stratify = int_labels)
    

#Pre-process pictures for modelling
    print('Pre-processing pictures')
    train_images, test_images = train_images / 255.0, test_images / 255.0

#Reminder of baseline (updated to reflect number of loaded images):
    baseline_scores=[]
    for label in list(set(test_labels)):
        number_of_images = test_labels.count(label)
        pc_of_images = number_of_images / len(test_labels)
        print(inv_breed_dict[label],'; number of images: ',
              number_of_images, '; % of images', pc_of_images)
        baseline_scores.append(pc_of_images)
    baseline = max(baseline_scores)
    print('Baseline: ', baseline)
    
    return train_images, test_images, train_labels, test_labels, inv_breed_dict, baseline

# %%
#Set up third model definition to include dropouts.
def def_model3(outshape, pic_size = (400,400,3)):
    model = models.Sequential()
    model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=pic_size))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Dropout(0.2))
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Dropout(0.2))
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.Flatten())
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(outshape, activation='softmax'))

    model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
    es = EarlyStopping(monitor = 'val_acc', min_delta = 0.0001, restore_best_weights=True)
    return model, es

# %%
#Set up fourth model definition to include a further 2 layers.
def def_model4(outshape, pic_size = (400,400,3)):
    model = models.Sequential()
    model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=pic_size))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Dropout(0.2))
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Dropout(0.2))
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Dropout(0.2))
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Dropout(0.2))
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.Flatten())
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(outshape, activation='softmax'))

    model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
    es = EarlyStopping(monitor = 'val_acc', min_delta = 0.0001, restore_best_weights=True)
    return model, es

# %%
#Define functions for reviewing results
def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array, true_label[i], img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])

    plt.imshow(img, cmap=plt.cm.binary)

    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'green'
    else:
        color = 'red'

    plt.xlabel("{} {:2.0f}% ({})".format(inv_breed_dict[predicted_label],
                                100*np.max(predictions_array),
                                inv_breed_dict[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array, true_label[i]
    plt.grid(False)
    plt.xticks(range(len(predictions_array)))
    plt.yticks([])
    thisplot = plt.bar(range(len(predictions_array)), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        thisplot[predicted_label].set_color('green')
        thisplot[true_label].set_color('green')
    if predicted_label != true_label:
        thisplot[predicted_label].set_color('red')
        thisplot[true_label].set_color('pink')

# %%
def review_results(predictions, test_labels, test_images, sample_size = 10):
    
    for counter in range(sample_size):
        i = random.randint(0,len(test_labels)-1)
        print(i)
        print(inv_breed_dict)
        plt.figure(figsize=(6,3))
        plt.subplot(1,2,1)
        plot_image(i, predictions[i], test_labels, test_images)
        plt.subplot(1,2,2)
        plot_value_array(i, predictions[i],  test_labels)
        plt.show()

# %%
def summarize_diagnostics(history):
    fig, ax = plt.subplots(nrows=2)
    # plot loss
    ax[0].plot(history.history['loss'], color='blue', label='train')
    ax[0].plot(history.history['val_loss'], color='orange', label='test')
    ax[0].set_title('Loss')
    # plot accuracy
    ax[1].plot(history.history['acc'], color='blue', label='train')
    ax[1].plot(history.history['val_acc'], color='orange', label='test')
    ax[1].set_title('Acc')
    fig.tight_layout()
    plt.show();

# %%
def model_documentation_nn(model_summary,
                           model, breed_list, training_sample_size,
                           pic_resolution, pic_masked, pic_quality,
                           baseline_score, validation_score,
                           train_score, test_score,
                           time_taken, notes):
    num_dog_breeds = len(breed_list)
    stringlist = []
    model.summary(print_fn=lambda x: stringlist.append(x))
    short_model_summary = "\n".join(stringlist)
    model_summary = model_summary.append({
        'model_type' : type(model),
        'model_parameters' : short_model_summary,
        'number_dog_breeds' : num_dog_breeds,
        'dog_breeds' : breed_list,
        'training_sample_size' : training_sample_size,
        'picture_resolution' : pic_resolution,
        'pictures_masked' : pic_masked,
        'picture_quality' : pic_quality,
        'baseline_score' : baseline_score,
        'validation_score' : validation_score,
        'train_score' : train_score,
        'test_score' : test_score,
        'time_taken' : time_taken,
        'notes' : notes},
        ignore_index = True)
#Display latest entry
    last_row = model_summary.shape[0]-1
    print(model_summary.iloc[last_row])
    return model_summary

# %% [markdown]
# ## Set up 1st dataset and model summary dataframe
# 3 breeds: labrador, cocker spaniel and french bulldog

# %%
breed_list = ['labrador', 'cocker_spaniel', 'french_bulldog']
clean = 'y'
threshold = 30
pic_size = (400, 400, 3)
train_images, test_images, train_labels, test_labels, inv_breed_dict, baseline =\
generate_image_set(breed_list, clean, threshold, pic_size)
# Out:
# Loading pictures...
# Setting up numpy array
# Number of loaded images:  2589
# Number of labels:  2589
# {'labrador': 0, 'cocker_spaniel': 1, 'french_bulldog': 2}
# {0: 'labrador', 1: 'cocker_spaniel', 2: 'french_bulldog'}
# Setting up train/test split
# Pre-processing pictures
# labrador ; number of images:  210 ; % of images 0.40540540540540543
# cocker_spaniel ; number of images:  193 ; % of images 0.37258687258687256
# french_bulldog ; number of images:  115 ; % of images 0.222007722007722
# Baseline:  0.40540540540540543

# %%
#Set up temporary model summary dataframe
master_model_summary = pd.read_pickle('model_summary.pkl')
temp_model_summary = pd.DataFrame(columns=master_model_summary.columns)

# %% [markdown]
# Introduce first transformation - horizontal flip and random rotations.

# %% [markdown]
# ### Test image augmentation

# %%
data = np.asarray(image.imread('clean_dog_pics/00003_pomchi_34.jpg'))
plt.imshow(data)

# %%
data = np.expand_dims(data, 0)
test_gen = ImageDataGenerator(horizontal_flip=True)
test_it = test_gen.flow(data, batch_size = 1)

# %%
for i in range (9):
    plt.subplot(330+1+i)
    batch = test_it.next()
    pic = batch[0].astype('uint8')
    plt.imshow(pic)
plt.show()

# %%
test_gen2 = ImageDataGenerator(rotation_range = 90, fill_mode='constant', cval = 0)
test_it2 = test_gen2.flow(data, batch_size = 1)
for i in range (9):
    plt.subplot(330+1+i)
    batch = test_it2.next()
    pic = batch[0].astype('uint8')
    plt.imshow(pic)
plt.show()

# %%
train_datagen = ImageDataGenerator(horizontal_flip=True,
                                   rotation_range = 90,
                                   fill_mode='constant',
                                   cval = 0,
                                   validation_split=0.2)
train_generator = train_datagen.flow(train_images, train_labels, subset='training', batch_size = 32)
val_datagen = ImageDataGenerator(validation_split=0.2)
val_generator = val_datagen.flow(train_images, train_labels, subset='validation', batch_size = 32)

# %%
start_time = time.time()
model, es = def_model3(len(breed_list), pic_size)
es = EarlyStopping(monitor = 'val_acc', min_delta = 0.0001, 
                   patience=10, restore_best_weights=True)
history = model.fit_generator(train_generator, 
                    epochs=50, 
                    validation_data = val_generator,
                    validation_steps =  0.2 * len(train_images) / 32,
                    callbacks = [es])
print("Model accuracy")
best_model_index = history.history['val_acc'].index(max(history.history['val_acc']))
val_acc = history.history['val_acc'][best_model_index]
train_acc = history.history['acc'][best_model_index]
test_loss, test_acc = model.evaluate(test_images, test_labels)
model_time = time.time() - start_time
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0906 12:43:46.229995 140036667234048 deprecation.py:506] From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Epoch 1/50
# 52/52 [==============================] - 47s 900ms/step - loss: 1.5582 - acc: 0.3603 - val_loss: 1.0756 - val_acc: 0.3841
# Epoch 2/50
# 52/52 [==============================] - 49s 937ms/step - loss: 1.0846 - acc: 0.3923 - val_loss: 1.0716 - val_acc: 0.4130
# Epoch 3/50
# 52/52 [==============================] - 49s 938ms/step - loss: 1.0787 - acc: 0.3917 - val_loss: 1.0653 - val_acc: 0.4082
# Epoch 4/50
# 52/52 [==============================] - 49s 941ms/step - loss: 1.0687 - acc: 0.4007 - val_loss: 1.0514 - val_acc: 0.4130
# Epoch 5/50
# 52/52 [==============================] - 49s 943ms/step - loss: 1.0671 - acc: 0.3971 - val_loss: 1.0303 - val_acc: 0.3986
# Epoch 6/50
# 52/52 [==============================] - 49s 943ms/step - loss: 1.0489 - acc: 0.3983 - val_loss: 1.0189 - val_acc: 0.3961
# Epoch 7/50
# 52/52 [==============================] - 49s 938ms/step - loss: 1.0438 - acc: 0.4110 - val_loss: 1.0144 - val_acc: 0.4493
# Epoch 8/50
# 52/52 [==============================] - 49s 942ms/step - loss: 1.0292 - acc: 0.4369 - val_loss: 1.0067 - val_acc: 0.4034
# Epoch 9/50
# 52/52 [==============================] - 49s 937ms/step - loss: 1.0262 - acc: 0.4363 - val_loss: 0.9965 - val_acc: 0.5169
# Epoch 10/50
# 52/52 [==============================] - 49s 942ms/step - loss: 1.0267 - acc: 0.4291 - val_loss: 0.9707 - val_acc: 0.5217
# Epoch 11/50
# 52/52 [==============================] - 49s 940ms/step - loss: 1.0124 - acc: 0.4532 - val_loss: 0.9452 - val_acc: 0.5266
# Epoch 12/50
# 52/52 [==============================] - 49s 941ms/step - loss: 1.0022 - acc: 0.4756 - val_loss: 0.9273 - val_acc: 0.5314
# Epoch 13/50
# 52/52 [==============================] - 49s 943ms/step - loss: 0.9839 - acc: 0.4725 - val_loss: 0.9234 - val_acc: 0.4928
# Epoch 14/50
# 52/52 [==============================] - 49s 939ms/step - loss: 0.9670 - acc: 0.4967 - val_loss: 0.8939 - val_acc: 0.4879
# Epoch 15/50
# 52/52 [==============================] - 49s 941ms/step - loss: 0.9426 - acc: 0.5063 - val_loss: 0.8953 - val_acc: 0.5121
# Epoch 16/50
# 52/52 [==============================] - 49s 939ms/step - loss: 0.9455 - acc: 0.5094 - val_loss: 0.9086 - val_acc: 0.4976
# Epoch 17/50
# 52/52 [==============================] - 49s 938ms/step - loss: 0.9383 - acc: 0.5365 - val_loss: 0.8700 - val_acc: 0.5048
# Epoch 18/50
# 52/52 [==============================] - 49s 940ms/step - loss: 0.9112 - acc: 0.5347 - val_loss: 0.8757 - val_acc: 0.4976
# Epoch 19/50
# 52/52 [==============================] - 49s 939ms/step - loss: 0.9286 - acc: 0.5202 - val_loss: 0.8723 - val_acc: 0.4855
# Epoch 20/50
# 52/52 [==============================] - 49s 941ms/step - loss: 0.9297 - acc: 0.5275 - val_loss: 0.8562 - val_acc: 0.5072
# Epoch 21/50
# 52/52 [==============================] - 49s 943ms/step - loss: 0.9076 - acc: 0.5456 - val_loss: 0.8702 - val_acc: 0.5145
# Epoch 22/50
# 52/52 [==============================] - 49s 950ms/step - loss: 0.9101 - acc: 0.5281 - val_loss: 0.8537 - val_acc: 0.5193
# Model accuracy
# 518/518 [==============================] - 2s 4ms/sample - loss: 0.9590 - acc: 0.5135

# %%
summarize_diagnostics(history)

# %%
notes = 'NN - model 3 + IA. Resolution of pictures test'
temp_model_summary = model_documentation_nn(temp_model_summary, model,
                                            breed_list, len(train_images), 
                                            train_images[0].shape,
                                            clean, threshold,
                                            baseline, val_acc,
                                            train_acc, test_acc,
                                            model_time, notes)
# Out:
# baseline_score                                                   0.405405
# dog_breeds                     [labrador, cocker_spaniel, french_bulldog]
# model                                                                 NaN
# model_parameters        Model: "sequential"\n_________________________...
# model_type              <class 'tensorflow.python.keras.engine.sequent...
# notes                      NN - model 3 + IA. Resolution of pictures test
# number_dog_breeds                                                       3
# picture_quality                                                        30
# picture_resolution                                          (400, 400, 3)
# pictures_masked                                                         y
# test_score                                                       0.513514
# time_taken                                                        1079.48
# train_score                                                      0.475558
# training_sample_size                                                 2071
# validation_score                                                 0.531401
# Name: 0, dtype: object

# %%
overall_history=[]
for i in [375, 350, 325, 300, 275, 250, 225, 200, 175, 150, 125, 100, 75, 50]:
    print('Resolution', i)
    pic_size = (i, i, 3)
    train_images, test_images, train_labels, test_labels, inv_breed_dict, baseline =\
    generate_image_set(breed_list, clean, threshold, pic_size)
    print('Total number of pictures: ', len(train_images))
    train_generator = train_datagen.flow(train_images, train_labels, 
                                         subset='training', batch_size = 32)
    val_generator = val_datagen.flow(train_images, train_labels, 
                                     subset='validation', batch_size = 32)
    start_time = time.time()
    model, es = def_model3(len(breed_list), pic_size)
    es = EarlyStopping(monitor = 'val_acc', min_delta = 0.0001, 
                       patience=10, restore_best_weights=True)
    history = model.fit_generator(train_generator, epochs=50, validation_data = val_generator,
                                  validation_steps =  0.2 * len(train_images) / 32,
                                  callbacks = [es])
    overall_history.append([i, history.history])
    print("Model accuracy")
    best_model_index = history.history['val_acc'].index(max(history.history['val_acc']))
    val_acc = history.history['val_acc'][best_model_index]
    train_acc = history.history['acc'][best_model_index]
    test_loss, test_acc = model.evaluate(test_images, test_labels)
    model_time = time.time() - start_time
    notes = 'NN - model 3 + IA. Number of pictures test'
    temp_model_summary = model_documentation_nn(temp_model_summary, model,
                                                breed_list, len(train_images), 
                                                train_images[0].shape,
                                                clean, threshold,
                                                baseline, val_acc,
                                                train_acc, test_acc, model_time, notes)
# Out:
# Resolution 375
# Loading pictures...
# Setting up numpy array
# Number of loaded images:  2589
# Number of labels:  2589
# {'labrador': 0, 'cocker_spaniel': 1, 'french_bulldog': 2}
# {0: 'labrador', 1: 'cocker_spaniel', 2: 'french_bulldog'}
# Setting up train/test split
# Pre-processing pictures
# labrador ; number of images:  210 ; % of images 0.40540540540540543
# cocker_spaniel ; number of images:  193 ; % of images 0.37258687258687256
# french_bulldog ; number of images:  115 ; % of images 0.222007722007722
# Baseline:  0.40540540540540543
# Total number of pictures:  2071
# Epoch 1/50
# 52/52 [==============================] - 44s 840ms/step - loss: 1.5937 - acc: 0.3754 - val_loss: 1.0742 - val_acc: 0.4130
# Epoch 2/50
# 52/52 [==============================] - 43s 827ms/step - loss: 1.0750 - acc: 0.4062 - val_loss: 1.0599 - val_acc: 0.4130
# Epoch 3/50
# 52/52 [==============================] - 43s 827ms/step - loss: 1.0668 - acc: 0.3941 - val_loss: 1.0531 - val_acc: 0.4300
# Epoch 4/50
# 52/52 [==============================] - 43s 827ms/step - loss: 1.0613 - acc: 0.4068 - val_loss: 1.0261 - val_acc: 0.4203
# Epoch 5/50
# 52/52 [==============================] - 43s 829ms/step - loss: 1.0493 - acc: 0.4212 - val_loss: 0.9985 - val_acc: 0.4614
# Epoch 6/50
# 52/52 [==============================] - 43s 829ms/step - loss: 1.0501 - acc: 0.4080 - val_loss: 0.9938 - val_acc: 0.4300
# Epoch 7/50
# 52/52 [==============================] - 43s 829ms/step - loss: 1.0322 - acc: 0.4297 - val_loss: 0.9968 - val_acc: 0.4130
# Epoch 8/50
# 52/52 [==============================] - 43s 828ms/step - loss: 1.0308 - acc: 0.4152 - val_loss: 0.9741 - val_acc: 0.4614
# Epoch 9/50
# 52/52 [==============================] - 43s 827ms/step - loss: 1.0229 - acc: 0.4412 - val_loss: 0.9647 - val_acc: 0.4710
# Epoch 10/50
# 52/52 [==============================] - 43s 826ms/step - loss: 1.0029 - acc: 0.4611 - val_loss: 0.9396 - val_acc: 0.5000
# Epoch 11/50
# 52/52 [==============================] - 43s 827ms/step - loss: 1.0070 - acc: 0.4768 - val_loss: 0.9337 - val_acc: 0.5121
# Epoch 12/50
# 52/52 [==============================] - 43s 826ms/step - loss: 0.9752 - acc: 0.5003 - val_loss: 0.9144 - val_acc: 0.5097
# Epoch 13/50
# 52/52 [==============================] - 43s 829ms/step - loss: 0.9576 - acc: 0.5057 - val_loss: 0.9163 - val_acc: 0.4903
# Epoch 14/50
# 52/52 [==============================] - 43s 835ms/step - loss: 0.9595 - acc: 0.5039 - val_loss: 0.8893 - val_acc: 0.5000
# Epoch 15/50
# 52/52 [==============================] - 43s 832ms/step - loss: 0.9608 - acc: 0.5009 - val_loss: 0.8936 - val_acc: 0.5217
# Epoch 16/50
# 52/52 [==============================] - 43s 829ms/step - loss: 0.9446 - acc: 0.5160 - val_loss: 0.8501 - val_acc: 0.5338
# Epoch 17/50
# 52/52 [==============================] - 43s 830ms/step - loss: 0.9369 - acc: 0.5305 - val_loss: 0.8801 - val_acc: 0.5531
# Epoch 18/50
# 52/52 [==============================] - 43s 830ms/step - loss: 0.9283 - acc: 0.5305 - val_loss: 0.8473 - val_acc: 0.5386
# Epoch 19/50
# 52/52 [==============================] - 43s 828ms/step - loss: 0.
50
# 52/52 [==============================] - 2s 41ms/step - loss: 0.7336 - acc: 0.6657 - val_loss: 0.6915 - val_acc: 0.6643
# Epoch 38/50
# 52/52 [==============================] - 2s 42ms/step - loss: 0.7377 - acc: 0.6482 - val_loss: 0.6784 - val_acc: 0.7005
# Epoch 39/50
# 52/52 [==============================] - 2s 40ms/step - loss: 0.7322 - acc: 0.6608 - val_loss: 0.6860 - val_acc: 0.6739
# Epoch 40/50
# 52/52 [==============================] - 2s 41ms/step - loss: 0.7508 - acc: 0.6524 - val_loss: 0.6844 - val_acc: 0.6812
# Epoch 41/50
# 52/52 [==============================] - 2s 42ms/step - loss: 0.7281 - acc: 0.6614 - val_loss: 0.6587 - val_acc: 0.7126
# Epoch 42/50
# 52/52 [==============================] - 2s 40ms/step - loss: 0.7123 - acc: 0.6596 - val_loss: 0.6935 - val_acc: 0.6329
# Epoch 43/50
# 52/52 [==============================] - 2s 41ms/step - loss: 0.7594 - acc: 0.6512 - val_loss: 0.6662 - val_acc: 0.6884
# Epoch 44/50
# 52/52 [==============================] - 2s 41ms/step - loss: 0.7126 - acc: 0.6657 - val_loss: 0.7075 - val_acc: 0.6570
# Epoch 45/50
# 52/52 [==============================] - 2s 41ms/step - loss: 0.7250 - acc: 0.6596 - val_loss: 0.6664 - val_acc: 0.6860
# Epoch 46/50
# 52/52 [==============================] - 2s 40ms/step - loss: 0.7046 - acc: 0.6735 - val_loss: 0.6930 - val_acc: 0.6884
# Epoch 47/50
# 52/52 [==============================] - 2s 41ms/step - loss: 0.6863 - acc: 0.6850 - val_loss: 0.6865 - val_acc: 0.6860
# Epoch 48/50
# 52/52 [==============================] - 2s 41ms/step - loss: 0.6904 - acc: 0.6922 - val_loss: 0.7062 - val_acc: 0.6739
# Epoch 49/50
# 52/52 [==============================] - 2s 41ms/step - loss: 0.6901 - acc: 0.6838 - val_loss: 0.6689 - val_acc: 0.6643
# Epoch 50/50
# 52/52 [==============================] - 2s 41ms/step - loss: 0.6907 - acc: 0.6771 - val_loss: 0.6624 - val_acc: 0.7053
# Model accuracy
# 518/518 [==============================] - 0s 124us/sample - loss: 0.6557 - acc: 0.7336
# baseline_score                                                   0.405405
# dog_breeds                     [labrador, cocker_spaniel, french_bulldog]
# model                                                                 NaN
# model_parameters        Model: "sequential_14"\n______________________...
# model_type              <class 'tensorflow.python.keras.engine.sequent...
# notes                          NN - model 3 + IA. Number of pictures test
# number_dog_breeds                                                       3
# picture_quality                                                        30
# picture_resolution                                            (75, 75, 3)
# pictures_masked                                                         y
# test_score                                                       0.733591
# time_taken                                                        108.309
# train_score                                                      0.661436
# training_sample_size                                                 2071
# validation_score                                                  0.71256
# Name: 13, dtype: object
# Resolution 50
# Loading pictures...
# Setting up numpy array
# Number of loaded images:  2589
# Number of labels:  2589
# {'labrador': 0, 'cocker_spaniel': 1, 'french_bulldog': 2}
# {0: 'labrador', 1: 'cocker_spaniel', 2: 'french_bulldog'}
# Setting up train/test split
# Pre-processing pictures
# labrador ; number of images:  210 ; % of images 0.40540540540540543
# cocker_spaniel ; number of images:  193 ; % of images 0.37258687258687256
# french_bulldog ; number of images:  115 ; % of images 0.222007722007722
# Baseline:  0.40540540540540543
# Total number of pictures:  2071
# Epoch 1/50
# 52/52 [==============================] - 3s 59ms/step - loss: 1.0868 - acc: 0.3881 - val_loss: 1.0618 - val_acc: 0.4396
# Epoch 2/50
# 52/52 [==============================] - 1s 20ms/step - loss: 1.0656 - acc: 0.3844 - val_loss: 1.0551 - val_acc: 0.4106
# Epoch 3/50
# 52/52 [==============================] - 1s 23ms/step - loss: 1.0536 - acc: 0.4218 - val_loss: 1.0217 - val_acc: 0.4372
# Epoch 4/50
# 52/52 [==============================] - 1s 23ms/step - loss: 1.0432 - acc: 0.4225 - val_loss: 1.0555 - val_acc: 0.4372
# Epoch 5/50
# 52/52 [==============================] - 1s 23ms/step - loss: 1.0321 - acc: 0.4436 - val_loss: 1.0418 - val_acc: 0.4275
# Epoch 6/50
# 52/52 [==============================] - 1s 23ms/step - loss: 1.0453 - acc: 0.4243 - val_loss: 0.9979 - val_acc: 0.4710
# Epoch 7/50
# 52/52 [==============================] - 1s 23ms/step - loss: 1.0205 - acc: 0.4514 - val_loss: 0.9770 - val_acc: 0.4758
# Epoch 8/50
# 52/52 [==============================] - 1s 23ms/step - loss: 1.0073 - acc: 0.4731 - val_loss: 0.9641 - val_acc: 0.5242
# Epoch 9/50
# 52/52 [==============================] - 1s 23ms/step - loss: 0.
50
# 52/52 [==============================] - 1s 23ms/step - loss: 0.7110 - acc: 0.6657 - val_loss: 0.7258 - val_acc: 0.6425
# Epoch 43/50
# 52/52 [==============================] - 1s 23ms/step - loss: 0.7161 - acc: 0.6777 - val_loss: 0.6928 - val_acc: 0.6329
# Epoch 44/50
# 52/52 [==============================] - 1s 23ms/step - loss: 0.7256 - acc: 0.6620 - val_loss: 0.7237 - val_acc: 0.6715
# Epoch 45/50
# 52/52 [==============================] - 1s 23ms/step - loss: 0.7131 - acc: 0.6753 - val_loss: 0.7074 - val_acc: 0.6425
# Epoch 46/50
# 52/52 [==============================] - 2s 32ms/step - loss: 0.6966 - acc: 0.6801 - val_loss: 0.6856 - val_acc: 0.6667
# Model accuracy
# 518/518 [==============================] - 0s 89us/sample - loss: 0.7247 - acc: 0.6660
# baseline_score                                                   0.405405
# dog_breeds                     [labrador, cocker_spaniel, french_bulldog]
# model                                                                 NaN
# model_parameters        Model: "sequential_15"\n______________________...
# model_type              <class 'tensorflow.python.keras.engine.sequent...
# notes                          NN - model 3 + IA. Number of pictures test
# number_dog_breeds                                                       3
# picture_quality                                                        30
# picture_resolution                                            (50, 50, 3)
# pictures_masked                                                         y
# test_score                                                       0.666023
# time_taken                                                        58.7445
# train_score                                                      0.650573
# training_sample_size                                                 2071
# validation_score                                                 0.690821
# Name: 14, dtype: object

# %%
plt.scatter(x = temp_model_summary['picture_resolution'],
            temp_model_summary['validation_score'])
plt.title('Validation scores against number of pictures in training set\nBreed selection 1\nClean images, NN model 3 + image augmentation')
plt.savefig('resolution_of_images_impact.jpg', bbox_inches ='tight')
plt.show()
# Out:
#   File "<ipython-input-29-f9d525a971e5>", line 2
#     temp_model_summary['validation_score'])
#     ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# ## Save results to model summary dataframe

# %%
temp_model_summary
# Out:
#     baseline_score                                  dog_breeds  model  \
# 0         0.405405  [labrador, cocker_spaniel, french_bulldog]    NaN
# 1         0.405405  [labrador, cocker_spaniel, french_bulldog]    NaN
# 2         0.405405  [labrador, cocker_spaniel, french_bulldog]    NaN
# 3         0.405405  [labrador, cocker_spaniel, french_bulldog]    NaN
# 4         0.405405  [labrador, cocker_spaniel, french_bulldog]    NaN
# 5         0.405405  [labrador, cocker_spaniel, french_bulldog]    NaN
# 6         0.405405  [labrador, cocker_spaniel, french_bulldog]    NaN
# 7         0.405405  [labrador, cocker_spaniel, french_bulldog]    NaN
# 8         0.405405  [labrador, cocker_spaniel, french_bulldog]    NaN
# 9         0.405405  [labrador, cocker_spaniel, french_bulldog]    NaN
# 10        0.405405  [labrador, cocker_spaniel, french_bulldog]    NaN
# 11        0.405405  [labrador, cocker_spaniel, french_bulldog]    NaN
# 12        0.405405  [labrador, cocker_spaniel, french_bulldog]    NaN
# 13        0.405405  [labrador, cocker_spaniel, french_bulldog]    NaN
# 14        0.405405  [labrador, cocker_spaniel, french_bulldog]    NaN
#
#                                      model_parameters  \
# 0   Model: "sequential"\n_________________________...
# 1   Model: "sequential_2"\n_______________________...
# 2   Model: "sequential_3"\n_______________________...
# 3   Model: "sequential_4"\n_______________________...
# 4   Model: "sequential_5"\n_______________________...
# 5   Model: "sequential_6"\n_______________________...
# 6   Model: "sequential_7"\n_______________________...
# 7   Model: "sequential_8"\n_______________________...
# 8   Model: "sequential_9"\n_______________________...
# 9   Model: "sequential_10"\n______________________...
# 10  Model: "sequential_11"\n______________________...
# 11  Model: "sequential_12"\n______________________...
# 12  Model: "sequential_13"\n______________________...
# 13  Model: "sequential_14"\n______________________...
# 14  Model: "sequential_15"\n______________________...
#
#                                            model_type  \
# 0   <class 'tensorflow.python.keras.engine.sequent...
# 1   <class 'tensorflow.python.keras.engine.sequent...
# 2   <class 'tensorflow.python.keras.engine.sequent...
# 3   <class 'tensorflow.python.keras.engine.sequent...
# 4   <class 'tensorflow.python.keras.engine.sequent...
# 5   <class 'tensorflow.python.keras.engine.sequent...
# 6   <class 'tensorflow.python.keras.engine.sequent...
# 7   <class 'tensorflow.python.keras.engine.sequent...
# 8   <class 'tensorflow.python.keras.engine.sequent...
# 9   <class 'tensorflow.python.keras.engine.sequent...
# 10  <class 'tensorflow.python.keras.engine.sequent...
# 11  <class 'tensorflow.python.keras.engine.sequent...
# 12  <class 'tensorflow.python.keras.engine.sequent...
# 13  <class 'tensorflow.python.keras.engine.sequent...
# 14  <class 'tensorflow.python.keras.engine.sequent...
#
#                                              notes number_dog_breeds  \
# 0   NN - model 3 + IA. Resolution of pictures test                 3
# 1       NN - model 3 + IA. Number of pictures test                 3
# 2       NN - model 3 + IA. Number of pictures test                 3
# 3       NN - model 3 + IA. Number of pictures test                 3
# 4       NN - model 3 + IA. Number of pictures test                 3
# 5       NN - model 3 + IA. Number of pictures test                 3
# 6       NN - model 3 + IA. Number of pictures test                 3
# 7       NN - model 3 + IA. Number of pictures test                 3
# 8       NN - model 3 + IA. Number of pictures test                 3
# 9       NN - model 3 + IA. Number of pictures test                 3
# 10      NN - model 3 + IA. Number of pictures test                 3
# 11      NN - model 3 + IA. Number of pictures test                 3
# 12      NN - model 3 + IA. Number of pictures test                 3
# 13      NN - model 3 + IA. Number of pictures test                 3
# 14      NN - model 3 + IA. Number of pictures test                 3
#
#    picture_quality picture_resolution pictures_masked  test_score  \
# 0               30      (400, 400, 3)               y    0.513514
# 1               30      (375, 375, 3)               y    0.610039
# 2               30      (350, 350, 3)               y    0.604247
# 3               30      (325, 325, 3)               y    0.606178
# 4               30      (300, 300, 3)               y    0.683398
# 5               30      (275, 275, 3)               y    0.666023
# 6               30      (250, 250, 3)               y    0.627413
# 7               30      (225, 225, 3)               y    0.592664
# 8               30      (200, 200, 3)               y    0.710425
# 9               30      (175, 175, 3)               y    0.501930
# 10              30      (150, 150, 3)               y    0.700772
# 11              30      (125, 125, 3)               y    0.702703
# 12              30      (100, 100, 3)               y    0.693050
# 13              30        (75, 75, 3)               y    0.733591
# 14              30        (50, 50, 3)               y    0.666023
#
#      time_taken  train_score training_sample_size  validation_score
# 0   1079.484485     0.475558                 2071          0.531401
# 1   2160.837282     0.628244                 2071          0.647343
# 2   1690.482498     0.608932                 2071          0.613527
# 3   1459.156816     0.576343                 2071          0.628019
# 4   1381.066265     0.637900                 2071          0.640097
# 5   1080.330714     0.605311                 2071          0.659420
# 6    896.481668     0.654798                 2071          0.654589
# 7    646.602184     0.605311                 2071          0.628019
# 8    587.294094     0.664454                 2071          0.681159
# 9    200.986642     0.529873                 2071          0.555556
# 10   343.086191     0.686180                 2071          0.688406
# 11   249.098135     0.672299                 2071          0.690821
# 12   170.141173     0.669885                 2071          0.678744
# 13   108.309157     0.661436                 2071          0.712560
# 14    58.744502     0.650573                 2071          0.690821

# %%
temp_model_summary.to_pickle('model_summary_clean_pics_CNN_3_breeds_res_of_pics.pkl')

# %%
temp_model_summary

# %%
model_summary = pd.read_pickle('model_summary.pkl')

# %%
model_summary.head()

# %%
model_summary.shape

# %%
model_summary = model_summary.append(temp_model_summary, ignore_index=True)

# %%
model_summary.tail()

# %%
#model_summary.to_pickle('model_summary.pkl')
